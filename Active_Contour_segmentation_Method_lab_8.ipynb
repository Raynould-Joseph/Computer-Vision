# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/Computer-Vision/blob/main/Active_Contour_segmentation_Method_lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Active contour (snakes)
import cv2
import matplotlib.pyplot as plt
# read the image
image = cv2.imread("/content/sample_data/water_coins.jpg",0)
# convert to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# create a binary thresholded image
_, binary = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)#Detected edges may supply as input
#<225 is set to 0 and >=225 is set to 255
# show it
plt.imshow(binary, cmap="gray")
plt.show()

# find the contours from the thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# RETR_EXTERNAL, contour retrival mode
#cv2.RETR_LIST: For extracting all contours without establishing any relationships
#CHAIN_APPROX_NONE -contour approxmation method-all boundary points are stored suppose 
#if we want to find contour of stright line then two points are sufficient so we give simple
# none will store all boundary points
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 2)#-1 display all contours
# show the image with the drawn contours
plt.imshow(image)
plt.show()

# %%
#Active contour (snakes)
import cv2
import matplotlib.pyplot as plt
# read the image
image = cv2.imread("/content/sample_data/water_coins_2.jpg",0)
# convert to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# create a binary thresholded image
_, binary = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)#Detected edges may supply as input
#<225 is set to 0 and >=225 is set to 255
# show it
plt.imshow(binary, cmap="gray")
plt.show()

# find the contours from the thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# RETR_EXTERNAL, contour retrival mode
#cv2.RETR_LIST: For extracting all contours without establishing any relationships
#CHAIN_APPROX_NONE -contour approxmation method-all boundary points are stored suppose 
#if we want to find contour of stright line then two points are sufficient so we give simple
# none will store all boundary points
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 2)#-1 display all contours
# show the image with the drawn contours
plt.imshow(image)
plt.show()
